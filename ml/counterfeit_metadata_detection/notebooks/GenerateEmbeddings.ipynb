# %%
import numpy as np
import pandas as pd

import pickle

# %%
from tensorflow.keras.models import load_model

from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
df = pd.read_csv(
    "authentic_metadata_output.csv"
)

df.head()
# Out:
#                   filename                                           metadata
# 0    normalized_nike_0.jpg  Nike Air Force 1 Low Brown Grey Classic Lifest...
# 1    normalized_nike_1.jpg  Nike Air Max Grey Black Classic Lifestyle Snea...
# 2   normalized_nike_10.jpg  Nike Air Force 1 Low Grey Charcoal Low Basketb...
# 3   normalized_nike_11.jpg     Nike Air Max Orange White Low Basketball Shoes
# 4  normalized_nike_112.jpg  Nike Dunk Low Purple Green Everyday Streetwear...

# %%
with open(
    "metadata_tokenizer_v1.pkl",
    "rb"
) as f:
    tokenizer=pickle.load(f)

# %%
encoder=load_model(
    "metadata_embedding_encoder_v1.keras"
)

# %%
metadata_texts=list(
    df["metadata"]
)

# %%
sequences=tokenizer.texts_to_sequences(
    metadata_texts
)

max_length=24

padded_sequences=pad_sequences(
    sequences,
    maxlen=max_length,
    padding='post'
)

# %%
metadata_embeddings=encoder.predict(
    padded_sequences
)

print(metadata_embeddings.shape)
# Out:
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# (2642, 128)

# %%
np.save(
    "metadata_embeddings.npy",
    metadata_embeddings
)

np.save(
    "metadata_texts.npy",
    np.array(metadata_texts)
)

np.save(
    "metadata_image_filenames.npy",
    df["filename"].values
)
